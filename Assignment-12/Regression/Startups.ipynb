# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
sns.set(rc={'figure.figsize':(10,10)},font_scale=1.3)
sns.set_palette('viridis')

# %%
df = pd.read_csv('50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.describe(include='all')
# Out:
#             R&D Spend  Administration  Marketing Spend     State  \
# count       50.000000       50.000000        50.000000        50
# unique            NaN             NaN              NaN         3
# top               NaN             NaN              NaN  New York
# freq              NaN             NaN              NaN        17
# mean     73721.615600   121344.639600    211025.097800       NaN
# std      45902.256482    28017.802755    122290.310726       NaN
# min          0.000000    51283.140000         0.000000       NaN
# 25%      39936.370000   103730.875000    129300.132500       NaN
# 50%      73051.080000   122699.795000    212716.240000       NaN
# 75%     101602.800000   144842.180000    299469.085000       NaN
# max     165349.200000   182645.560000    471784.100000       NaN
#
#                Profit
# count       50.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean    112012.639200
# std      40306.180338
# ...

# %%
for col in df.columns:
    print(f'For column {col}')
    print(f'{df[col].value_counts()}')
    print("*******************************************")
# Out:
# For column R&D Spend
# 0.00         2
# 123334.88    1
# 165349.20    1
# 38558.51     1
# 46014.02     1
# 20229.59     1
# 130298.13    1
# 55493.95     1
# 542.05       1
# 91992.39     1
# 65605.48     1
# 23640.93     1
# 162597.70    1
# 131876.90    1
# 67532.53     1
# 61136.38     1
# 119943.24    1
# 76253.86     1
# 72107.60     1
# 28663.76     1
# 44069.95     1
# 66051.52     1
# 78013.11     1
# 91749.16     1
# 27892.92     1
# 93863.75     1
# 100671.96    1
# 1315.46      1
# 134615.46    1
# 28754.33     1
# 78389.47     1
# 153441.51    1
# 46426.07     1
# 114523.61    1
# 22177.74     1
# 101913.08    1
# 63408.86     1
# 15505.73     1
# 64664.71     1
# 77044.01     1
# 86419.70     1
# 120542.52    1
# 144372.41    1
# 73994.56     1
# 142107.34    1
# 94657.16     1
# 75328.87     1
# 61994.48     1
# 1000.23      1
# Name: R&D Spend, dtype: int64
# *******************************************
# For column Administration
# 127382.30    1
# 148718.95    1
# ...

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(df['R&D Spend'],shade=True)
# Out:
# <AxesSubplot:xlabel='R&D Spend', ylabel='Density'>

# %%
sns.kdeplot(df['Administration'],shade=True)
# Out:
# <AxesSubplot:xlabel='Administration', ylabel='Density'>

# %%
sns.kdeplot(df['Marketing Spend'],shade=True)
# Out:
# <AxesSubplot:xlabel='Marketing Spend', ylabel='Density'>

# %%
sns.kdeplot(df['Profit'],shade=True)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.jointplot(y=df['R&D Spend'],x=df['Profit'])

# %%
sns.jointplot(df['Profit'],df['Administration'])

# %%
sns.jointplot(df['Profit'],df['Marketing Spend'])

# %%
sns.countplot(df['State'])
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %%
sns.boxplot(df['State'],df['Profit'])
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
sns.boxplot(df['State'],df['R&D Spend'])
# Out:
# <AxesSubplot:xlabel='State', ylabel='R&D Spend'>

# %%
sns.boxplot(df['State'],df['Administration'])
# Out:
# <AxesSubplot:xlabel='State', ylabel='Administration'>

# %%
States = {'New York':2,'California':1,'Florida':0}

# %%
df['State'] = df['State'].map(States)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import r2_score ,mean_absolute_error

# %%
x = df.drop('Profit',axis=1)
y = df['Profit']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=42,test_size=0.2)

# %%
models = [LinearRegression(),SVR(kernel='linear'),DecisionTreeRegressor(),DecisionTreeRegressor(),RandomForestRegressor(),
          MLPRegressor(hidden_layer_sizes=(16))]

# %%
for model in models:
    print(f'For model {model}')
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    print(f'R2 score = {r2_score(y_pred,y_test)}')
    print(f'Model score = {model.score(x_test,y_test)}')
    print(f'Mean Absolute Error = {mean_absolute_error(y_pred,y_test)}')
    print("***************************************************************")
# Out:
# For model LinearRegression()
# R2 score = 0.8862295370073877
# Model score = 0.8990092409390611
# Mean Absolute Error = 6966.298581157146
# ***************************************************************
# For model SVR(kernel='linear')
# R2 score = 0.8743883034021823
# Model score = 0.871825939118203
# Mean Absolute Error = 7702.088897502952
# ***************************************************************
# For model DecisionTreeRegressor()
# R2 score = 0.8426157501354669
# Model score = 0.7765181089757696
# Mean Absolute Error = 10436.618999999997
# ***************************************************************
# For model DecisionTreeRegressor()
# R2 score = 0.8877839939224386
# Model score = 0.7883424162659735
# Mean Absolute Error = 10274.728999999998
# ***************************************************************
# For model RandomForestRegressor()
# R2 score = 0.9175812324519871
# Model score = 0.8939130355853689
# Mean Absolute Error = 6572.159459999993
# ...

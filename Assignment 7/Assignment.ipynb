# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

sns.set(rc={'figure.figsize':[8,8]},font_scale=1.2)

# %%
df = pd.read_csv('50ulke.csv')
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %% [markdown]
# ### From the head of the dataframe we can figure out that we have 2 categorical data and 3 numerical data and in the cells below we're gonna manipulate the data with both categorical and numerical plots

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       50 non-null     int64
#  1   Countries        50 non-null     object
#  2   National Income  50 non-null     float64
#  3   Growth           50 non-null     float64
#  4   Per person       50 non-null     float64
#  5   Continent        50 non-null     object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.5+ KB

# %% [markdown]
# ### From the info above we can deduce that we have 50 rows and 6 columns ( 2 categorical and 3 numerical ) and Unnamed column
# ### We will drop the Unnamed column to not lead to any problem ahead

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#         Countries  National Income  Growth  Per person      Continent
# 0   United States         20412.87    2.27     62152.0  North America
# 1           China         14092.51    6.86     10088.0           Asia
# 2           Japan          5167.05    1.71     40849.0           Asia
# 3         Germany          4211.64    2.51     50842.0         Europe
# 4  United Kingdom          2936.29    1.79     44177.0         Europe

# %%
df.describe()
# Out:
#        National Income     Growth    Per person
# count        50.000000  50.000000     50.000000
# mean       1646.348200   3.320400  27696.000000
# std        3448.554429   2.053468  25094.131496
# min         231.570000  -0.740000   1615.000000
# 25%         353.440000   1.795000   6402.000000
# 50%         522.985000   2.880000  14565.500000
# 75%        1504.895000   4.287500  48738.250000
# max       20412.870000   7.810000  86835.000000

# %%
df['Countries'].value_counts()
# Out:
# Indonesia                   1
# United Arab Emirates        1
# Finland                     1
# Chile                       1
# Vietnam                     1
# Bangladesh                  1
# Ireland                     1
# Egypt                       1
# Poland                      1
# Romania                     1
# Taiwan Province of China    1
# Thailand                    1
# Canada                      1
# Hong Kong SAR               1
# Brazil                      1
# Japan                       1
# France                      1
# Turkey                      1
# Denmark                     1
# Switzerland                 1
# Mexico                      1
# Peru                        1
# Russia                      1
# Saudi Arabia                1
# China                       1
# Portugal                    1
# Sweden                      1
# Nigeria                     1
# South Africa                1
# Norway                      1
# Colombia                    1
# ...

# %%
df['National Income'].value_counts()
# Out:
# 285.82      1
# 369.76      1
# 614.19      1
# 2925.10     1
# 248.89      1
# 945.33      1
# 418.88      1
# 280.27      1
# 625.92      1
# 4211.64     1
# 324.73      1
# 1798.51     1
# 1506.44     1
# 20412.87    1
# 370.89      1
# 2848.23     1
# 1212.83     1
# 408.61      1
# 245.59      1
# 909.89      1
# 349.66      1
# 253.25      1
# 373.75      1
# 748.00      1
# 2138.92     1
# 251.58      1
# 562.23      1
# 443.25      1
# 385.14      1
# 364.78      1
# 1074.97     1
# 332.45      1
# 289.56      1
# 364.92      1
# 2936.29     1
# 14092.51    1
# 231.57      1
# 1719.90     1
# 613.30      1
# 477.67      1
# 240.78      1
# 1500.26     1
# 483.74      1
# 5167.05     1
# 327.98      1
# 600.77      1
# 2181.97     1
# 741.69      1
# 411.83      1
# 1693.25     1
# Name: National Income, dtype: int64

# %%
df['Per person'].value_counts()
# Out:
# 32775.0    1
# 11947.0    1
# 55185.0    1
# 39484.0    1
# 6459.0     1
# 42115.0    1
# 15087.0    1
# 2611.0     1
# 2135.0     1
# 6581.0     1
# 2265.0     1
# 48466.0    1
# 86835.0    1
# 52422.0    1
# 40849.0    1
# 59655.0    1
# 24237.0    1
# 80641.0    1
# 1734.0     1
# 2108.0     1
# 6992.0     1
# 1618.0     1
# 4052.0     1
# 10224.0    1
# 35914.0    1
# 82711.0    1
# 12575.0    1
# 53764.0    1
# 9723.0     1
# 6383.0     1
# 61767.0    1
# 44934.0    1
# 25977.0    1
# 11237.0    1
# 5086.0     1
# 58345.0    1
# 49272.0    1
# 14044.0    1
# 32559.0    1
# 44177.0    1
# 50842.0    1
# 7199.0     1
# 11114.0    1
# 48829.0    1
# 3095.0     1
# 2546.0     1
# 1615.0     1
# 2375.0     1
# 10088.0    1
# 62152.0    1
# Name: Per person, dtype: int64

# %%
df['Continent'].value_counts()
# Out:
# Asia             19
# Europe           19
# South America     5
# North America     3
# Africa            3
# Oceania           1
# Name: Continent, dtype: int64

# %% [markdown]
# ### We check if missing data using heatmap

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### From the plot, there's no missing data and we can use describtive method to make sure that there're no missing values

# %%
df.isnull().sum() * 100 / len(df)
# Out:
# Countries          0.0
# National Income    0.0
# Growth             0.0
# Per person         0.0
# Continent          0.0
# dtype: float64

# %% [markdown]
# ### Good news, No missing values

# %% [markdown]
# ### We'll start by univariate analysis and try to execute something useful from it

# %%
sns.distplot(df['Growth'])
# Out:
# <AxesSubplot:xlabel='Growth', ylabel='Density'>

# %% [markdown]
# ### We can observe that the growth is at its peak between 2 and 4

# %%
sns.distplot(df['Per person'],kde=False)
# Out:
# <AxesSubplot:xlabel='Per person'>

# %% [markdown]
# ### We can observe that Per person is at its peak in the intervals [0,20000] , [40000,60000]

# %%
sns.distplot(df['National Income'],kde=False)
# Out:
# <AxesSubplot:xlabel='National Income'>

# %% [markdown]
# ### The national income at peak between 200 and 2500 and there's outlier

# %%
sns.kdeplot(df['National Income'],shade=True)
# Out:
# <AxesSubplot:xlabel='National Income', ylabel='Density'>

# %% [markdown]
# ### The density of National Income is at its maximum between 200 and 5000

# %%
sns.kdeplot(df['Per person'],shade=True)
# Out:
# <AxesSubplot:xlabel='Per person', ylabel='Density'>

# %%
sns.kdeplot(df['Growth'],shade=True)
# Out:
# <AxesSubplot:xlabel='Growth', ylabel='Density'>

# %%
sns.jointplot(data=df,x='Growth',y='National Income')

# %% [markdown]
# ### The national income increases till growth reaches about 2.5 then it decreases

# %%
sns.jointplot(data=df,x='Growth',y='Per person')

# %%
sns.jointplot(data=df,y='Per person',x='National Income',kind='hex')

# %% [markdown]
# ### The national income is dense from 200 to 5000 related to Per person

# %%
sns.pairplot(data=df)

# %%
sns.boxplot(data=df,x='Continent',y='Per person')
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Per person'>

# %% [markdown]
# ### We can see that the income per person is very high in North America and Europe while it is the least in Africa

# %%
sns.boxplot(data=df,x='Continent',y='Growth')
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Growth'>

# %% [markdown]
# ### The growth is very high in Asia and kinda Europe and the least in Africa

# %%
sns.boxplot(data=df,x='Continent',y='National Income')
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='National Income'>

# %% [markdown]
# ### The National Income is very high in North America

# %%
sns.violinplot(data=df,x='Continent',y='National Income')
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='National Income'>

# %%
sns.violinplot(data=df,x='Continent',y='Growth')
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Growth'>

# %%
sns.countplot(data=df,x='Continent')
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='count'>

# %% [markdown]
# ### The data is dense in both Europe and Asia

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### We can see the dependance of Growth and Per person on each other is negative and they weakly depend on each other

# %%
df['Less3000'] = df['National Income']<=3000

# %%
sns.countplot(df['Less3000'],hue=df['Continent'])
# Out:
# <AxesSubplot:xlabel='Less3000', ylabel='count'>
